# %% [markdown]
# # Determining the Effect of Gun Laws
#
# By Hannah George
#
# Environment: conda_tensorflow2_p310

# %% [markdown]
# ## Imports

# %%
import pandas as pd

# %% [markdown]
# ## Read in Data

# %%
coef_df = pd.read_csv('lme_coefficients_v2.csv')
gun_topic_scores = pd.read_csv('gun_law_topic_scores_v2.csv')

# %%
coef_df.head()
# Out:
#    coef_topic_19  coef_topic_18  coef_topic_17  coef_topic_16  coef_topic_15  \
# 0      -0.081521       0.294618       1.871567       0.051114       1.683180
# 1      -0.000740      -0.016855      -0.008400      -0.005452      -0.015181
# 2       0.267743       0.024571       0.018572      -0.038548       0.447415
# 3      -0.134929      -0.014916       0.002127       0.004542      -0.023024
# 4      -4.543596       0.210182       2.190776      -0.000643       1.356163
#
#    coef_topic_14  coef_topic_13  coef_topic_12  coef_topic_11  coef_topic_10  \
# 0       0.073372      -0.195883       1.027221      -0.117567       0.153734
# 1       0.001378      -0.024944       0.019489      -0.001499      -0.005781
# 2       0.173617      -0.228490      -0.086345      -0.019668       0.057337
# 3      -0.031973       0.212617       0.023892      -0.001451      -0.167873
# 4      -1.242341      -0.749061       1.249213      -0.139358      -1.552359
#
# ...

# %%
gun_topic_scores.head()
# Out:
#    law_id   state                                            content  \
# 0  AK1002  Alaska  It is unlawful for a person to carry concealed...
# 1  AK1009  Alaska  Alaska Stat. § 11.61.220(a)(3): A person commi...
# 2  AK1011  Alaska  A person commits the crime of misconduct invol...
# 3  AK1015  Alaska  Alaska Stat. § 11.61.220(a)(3): A person commi...
# 4  AK1016  Alaska  A person commits the crime of misconduct invol...
#
#     topic_0   topic_1   topic_2   topic_3   topic_4   topic_5   topic_6  ...  \
# 0  0.595653  0.656855  0.055646  0.090330  0.789340  0.031487  0.200680  ...
# 1  0.513505  0.000000  1.055667  0.000000  0.109554  0.088013  0.000000  ...
# 2  0.896441  0.363862  0.001175  0.066113  1.008212  0.000000  0.104936  ...
# 3  0.513505  0.000000  1.055667  0.000000  0.109554  0.088013  0.000000  ...
# 4  0.896441  0.363862  0.001175  0.066113  1.008212  0.000000  0.104936  ...
#
#    topic_10  topic_11  topic_12  topic_13  topic_14  topic_15  topic_16  \
# ...

# %% [markdown]
# ## Computing the Effect of Each Gun Law

# %%
law_effect = coef_df.merge(gun_topic_scores, on='state')

# %%
topic_col_names = [f'topic_{i}' for i in range(20)]
coef_col_names = [f'coef_topic_{i}' for i in range(20)]

# %%
law_effect['effect'] = law_effect[topic_col_names].mul(
    law_effect[coef_col_names].values, axis=0).sum(axis=1)

# %%
law_effect.head()
# Out:
#    coef_topic_19  coef_topic_18  coef_topic_17  coef_topic_16  coef_topic_15  \
# 0      -0.081521       0.294618       1.871567       0.051114        1.68318
# 1      -0.081521       0.294618       1.871567       0.051114        1.68318
# 2      -0.081521       0.294618       1.871567       0.051114        1.68318
# 3      -0.081521       0.294618       1.871567       0.051114        1.68318
# 4      -0.081521       0.294618       1.871567       0.051114        1.68318
#
#    coef_topic_14  coef_topic_13  coef_topic_12  coef_topic_11  coef_topic_10  \
# 0       0.073372      -0.195883       1.027221      -0.117567       0.153734
# 1       0.073372      -0.195883       1.027221      -0.117567       0.153734
# 2       0.073372      -0.195883       1.027221      -0.117567       0.153734
# 3       0.073372      -0.195883       1.027221      -0.117567       0.153734
# 4       0.073372      -0.195883       1.027221      -0.117567       0.153734
#
# ...

# %%
law_effect.to_csv('gun_law_topics_effects_v2.csv', index=False)
